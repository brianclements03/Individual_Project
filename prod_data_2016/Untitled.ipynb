# %%
import pandas as pd
import numpy as np

# %%
prod_16_d1 = pd.read_csv('ProductionDataQuery_Lease_ReportCsv_2016_D1.csv', sep = ',')
prod_16_d1
# Out:
#                        Lease Name Lease No. District No. Well No.  Oil (BBL)  \
# 0                     ALTIZER "B"    167077           01       7B          0
# 1                          REEVES     12813           01                 441
# 2           (S.A.H.) V.H. HRBACEK     04024           01                   0
# 3                     0AUER, OLGA     02065           01                  82
# 4      1ST LOCKHART NATIONAL BANK     09481           01                   0
# ...                           ...       ...          ...      ...        ...
# 16400                 ZRZAVY UNIT     18191           01              290672
# 16401      ZUCK, S.V. STATE A2796    267754           01       1H          0
# 16402      ZUCK, S.V. STATE A2796    270509           01       2H          0
# 16403                ZUEHL, EDGAR     10291           01                   0
# 16404                       Total                                  191797547
#
#        Casinghead (MCF)  GW Gas (MCF)  Condensate (BBL)
# 0                     0         29948                 0
# 1                     0             0                 0
# 2                     0             0                 0
# 3                     0             0                 0
# 4                     0             0                 0
# ...                 ...           ...               ...
# 16400             85348             0                 0
# 16401                 0         69127                 0
# 16402                 0        117153                 0
# 16403                 0             0                 0
# 16404         347879757     979870642          45205664
#
# [16405 rows x 8 columns]

# %%
prod_16_d1['Production_year'] = 2016
prod_16_d1
# Out:
#                        Lease Name Lease No. District No. Well No.  Oil (BBL)  \
# 0                     ALTIZER "B"    167077           01       7B          0
# 1                          REEVES     12813           01                 441
# 2           (S.A.H.) V.H. HRBACEK     04024           01                   0
# 3                     0AUER, OLGA     02065           01                  82
# 4      1ST LOCKHART NATIONAL BANK     09481           01                   0
# ...                           ...       ...          ...      ...        ...
# 16400                 ZRZAVY UNIT     18191           01              290672
# 16401      ZUCK, S.V. STATE A2796    267754           01       1H          0
# 16402      ZUCK, S.V. STATE A2796    270509           01       2H          0
# 16403                ZUEHL, EDGAR     10291           01                   0
# 16404                       Total                                  191797547
#
#        Casinghead (MCF)  GW Gas (MCF)  Condensate (BBL)  Production_year
# 0                     0         29948                 0             2016
# 1                     0             0                 0             2016
# 2                     0             0                 0             2016
# 3                     0             0                 0             2016
# 4                     0             0                 0             2016
# ...                 ...           ...               ...              ...
# 16400             85348             0                 0             2016
# 16401                 0         69127                 0             2016
# 16402                 0        117153                 0             2016
# 16403                 0             0                 0             2016
# 16404         347879757     979870642          45205664             2016
#
# [16405 rows x 9 columns]

# %%
type(prod_16_d1['Well No.'])
# Out:
# pandas.core.series.Series

# %%
prod_16_d1['Lease Name'].nunique()
# Out:
# 9541

# %%
prod_16_d1['Lease Name'].value_counts()
# Out:
# PILONCILLO                    359
# GALVAN RANCH                  250
# SBR                           216
# BRISCOE CATARINA NORTH        140
# BRISCOE COCHINA EAST RANCH    140
#                              ...
# TAG UNIT                        1
# SWR "C"                         1
# FAITH BONITA Q UNIT             1
# FOSTER UNIT IV LAS              1
# PIENIAZEK, TEDDY                1
# Name: Lease Name, Length: 9541, dtype: int64

# %%
prod_16_d1[prod_16_d1['Lease Name'] == 'PILONCILLO']#['Well No.']
# Out:
#        Lease Name Lease No. District No. Well No.  Oil (BBL)  \
# 11841  PILONCILLO    263582           01    D  1H          0
# 11842  PILONCILLO    263876           01    A  4H          0
# 11843  PILONCILLO    264716           01    B  1H          0
# 11844  PILONCILLO    265393           01   D  4HD          0
# 11845  PILONCILLO    265394           01   D  4HA          0
# ...           ...       ...          ...      ...        ...
# 12195  PILONCILLO    282241           01   A 18HX          0
# 12196  PILONCILLO    282261           01   A 18HY          0
# 12197  PILONCILLO    282295           01   A 25HZ          0
# 12198  PILONCILLO    282297           01   A 18HZ          0
# 12199  PILONCILLO    282441           01   A 18HY          0
#
#        Casinghead (MCF)  GW Gas (MCF)  Condensate (BBL)  Production_year
# 11841                 0          8757               676             2016
# 11842                 0         14363               752             2016
# 11843                 0          6977              1174             2016
# 11844                 0         40609              2851             2016
# 11845                 0             0                 0             2016
# ...                 ...           ...               ...              ...
# 12195                 0         79933              8070             2016
# 12196                 0         94983             12019             2016
# 12197                 0             0                 0             2016
# 12198                 0         80583              8852             2016
# 12199                 0             0                 0             2016
#
# [359 rows x 9 columns]

# %%
permits = pd.read_csv('permits.csv')

# %%
permits.head(1)
# Out:
#   Permit_approved                               Status_Date  Status   API_NO.  \
# 0      2016-01-04  Submitted 01/04/2016 Approved 01/04/2016  812976  28531642
#
#               Operator_Name_Number          Lease_Name Well District  County  \
# 0  CANTERA OPERATING, LLC (129692)  O. A. LAMPLEY GU 1    1       02  LAVACA
#
#   Wellbore_Profile Filing_Purpose Amend  Total_Depth  \
# 0         Vertical   Recompletion     N        13606
#
#    Stacked_Lateral_Parent_Well_DP Current_Queue Permit_submitted  \
# 0                             NaN      APPROVED       2016-01-04
#
#   Approval_time       SHALE
# 0        0 days  EAGLE FORD

# %%
permits[permits['Lease_Name'] == 'PILONCILLO']

# %%
test = permits.merge(prod_16_d1,how='left',left_on=['Well_#'], right_on=['Well No.'])

# %%
test.isna().sum()

# %%
test.head()

# %%
test[~test["Lease Name"].isna()]

# %%
temp = pd.crosstab(permits.Lease_Name,permits['Well_#'])

# %%
temp

# %%
temp[(temp > 1).any(1)]

# %%
# drop duplicates where theses columns appear > 1, don't keep copies

# same, drop dups where this combo appears >1
