# %%
import pandas as pd
import numpy as np

# %%
permits = pd.read_csv('permits.csv')
prod_16 = pd.read_csv('prod_16.csv').drop(columns = ['Unnamed: 0'])

# %%
permits.shape, prod_16.shape
# Out:
# ((76899, 18), (227770, 9))

# %%
permits.Permit_approved = pd.to_datetime(permits.Permit_approved)

# %%
permits = permits.set_index(permits.Permit_approved)

# %%
permits.head(1)
# Out:
#                 Permit_approved                               Status_Date  \
# Permit_approved
# 2016-01-04           2016-01-04  Submitted 01/04/2016 Approved 01/04/2016
#
#                  Status   API_NO.             Operator_Name_Number  \
# Permit_approved
# 2016-01-04       812976  28531642  CANTERA OPERATING, LLC (129692)
#
#                          Lease_Name Well District  County Wellbore_Profile  \
# Permit_approved
# 2016-01-04       O. A. LAMPLEY GU 1    1       02  LAVACA         Vertical
#
#                 Filing_Purpose Amend  Total_Depth  \
# Permit_approved
# 2016-01-04        Recompletion     N        13606
#
#                  Stacked_Lateral_Parent_Well_DP Current_Queue  \
# Permit_approved
# 2016-01-04                                  NaN      APPROVED
#
#                 Permit_submitted Approval_time       SHALE
# Permit_approved
# 2016-01-04            2016-01-04        0 days  EAGLE FORD

# %%
permits['Approved_year'] = permits.index.year
permits.head(1)
# Out:
#                 Permit_approved                               Status_Date  \
# Permit_approved
# 2016-01-04           2016-01-04  Submitted 01/04/2016 Approved 01/04/2016
#
#                  Status   API_NO.             Operator_Name_Number  \
# Permit_approved
# 2016-01-04       812976  28531642  CANTERA OPERATING, LLC (129692)
#
#                          Lease_Name Well District  County Wellbore_Profile  \
# Permit_approved
# 2016-01-04       O. A. LAMPLEY GU 1    1       02  LAVACA         Vertical
#
#                 Filing_Purpose Amend  Total_Depth  \
# Permit_approved
# 2016-01-04        Recompletion     N        13606
#
#                  Stacked_Lateral_Parent_Well_DP Current_Queue  \
# Permit_approved
# 2016-01-04                                  NaN      APPROVED
#
#                 Permit_submitted Approval_time       SHALE  Approved_year
# Permit_approved
# 2016-01-04            2016-01-04        0 days  EAGLE FORD           2016

# %%
prod_16.head(1)
# Out:
#     Lease_Name Lease_No. District Well  Oil_BBL  Casinghead_MCF  GW_Gas_MCF  \
# 0  ALTIZER "B"    167077       01   7B        0               0       29948
#
#    Condensate_BBL  Production_year
# 0               0             2016

# %%
test = permits.merge(prod_16, how='left',left_on=['Approved_year','Lease_Name','Well'], right_on=['Production_year','Lease_Name','Well'])

# %%
test.T
# Out:
#                                                                    0      \
# Permit_approved                                      2016-01-04 00:00:00
# Status_Date                     Submitted 01/04/2016 Approved 01/04/2016
# Status                                                            812976
# API_NO.                                                         28531642
# Operator_Name_Number                     CANTERA OPERATING, LLC (129692)
# Lease_Name                                            O. A. LAMPLEY GU 1
# Well                                                                   1
# District_x                                                            02
# County                                                            LAVACA
# Wellbore_Profile                                                Vertical
# Filing_Purpose                                              Recompletion
# Amend                                                                  N
# ...

# %%
test.isna().sum()
# Out:
# Permit_approved                       0
# Status_Date                           0
# Status                                0
# API_NO.                               0
# Operator_Name_Number                  0
# Lease_Name                            0
# Well                                  0
# District_x                            0
# County                                0
# Wellbore_Profile                      5
# Filing_Purpose                        0
# Amend                                 0
# Total_Depth                           0
# Stacked_Lateral_Parent_Well_DP    71153
# Current_Queue                         0
# Permit_submitted                      0
# Approval_time                         0
# SHALE                                 2
# Approved_year                         0
# Lease_No.                         75746
# District_y                        75746
# Oil_BBL                           75746
# Casinghead_MCF                    75746
# ...

# %%
test.dropna()
# Out:
#      Permit_approved                               Status_Date  Status  \
# 533       2016-01-22  Submitted 12/07/2015 Approved 01/22/2016  812508
# 560       2016-01-25  Submitted 01/21/2016 Approved 01/25/2016  813386
# 1209      2016-02-17  Submitted 02/10/2016 Approved 02/17/2016  702832
# 1847      2016-03-15  Submitted 03/10/2016 Approved 03/15/2016  814353
# 2226      2016-03-30  Submitted 03/28/2016 Approved 03/30/2016  814643
# 3542      2016-05-16  Submitted 12/10/2015 Approved 05/16/2016  762217
# 3543      2016-05-16  Submitted 12/10/2015 Approved 05/16/2016  762205
# 4115      2016-06-02  Submitted 05/31/2016 Approved 06/02/2016  815985
# 4181      2016-06-06  Submitted 04/19/2016 Approved 06/06/2016  814643
# 5552      2016-07-25  Submitted 07/19/2016 Approved 07/25/2016  779154
# 7804      2016-10-04  Submitted 09/29/2016 Approved 10/04/2016  818934
# 7943      2016-10-07  Submitted 10/03/2016 Approved 10/07/2016  819058
#
# ...
