# %%
import pandas as pd
import numpy as np

# %%
permits = pd.read_csv('permits.csv')
prod_16 = pd.read_csv('prod_16.csv').drop(columns = ['Unnamed: 0'])

# %%
permits.shape, prod_16.shape
# Out:
# ((76899, 18), (227770, 9))

# %%
permits.Permit_approved = pd.to_datetime(permits.Permit_approved)

# %%
permits = permits.set_index(permits.Permit_approved)

# %%
permits.head(1)
# Out:
#                 Permit_approved                               Status_Date  \
# Permit_approved
# 2016-01-04           2016-01-04  Submitted 01/04/2016 Approved 01/04/2016
#
#                  Status   API_NO.             Operator_Name_Number  \
# Permit_approved
# 2016-01-04       812976  28531642  CANTERA OPERATING, LLC (129692)
#
#                          Lease_Name Well District  County Wellbore_Profile  \
# Permit_approved
# 2016-01-04       O. A. LAMPLEY GU 1    1       02  LAVACA         Vertical
#
#                 Filing_Purpose Amend  Total_Depth  \
# Permit_approved
# 2016-01-04        Recompletion     N        13606
#
#                  Stacked_Lateral_Parent_Well_DP Current_Queue  \
# Permit_approved
# 2016-01-04                                  NaN      APPROVED
#
#                 Permit_submitted Approval_time       SHALE
# Permit_approved
# 2016-01-04            2016-01-04        0 days  EAGLE FORD

# %%
permits['Approved_year'] = permits.index.year
permits.head(1)
# Out:
#                 Permit_approved                               Status_Date  \
# Permit_approved
# 2016-01-04           2016-01-04  Submitted 01/04/2016 Approved 01/04/2016
#
#                  Status   API_NO.             Operator_Name_Number  \
# Permit_approved
# 2016-01-04       812976  28531642  CANTERA OPERATING, LLC (129692)
#
#                          Lease_Name Well District  County Wellbore_Profile  \
# Permit_approved
# 2016-01-04       O. A. LAMPLEY GU 1    1       02  LAVACA         Vertical
#
#                 Filing_Purpose Amend  Total_Depth  \
# Permit_approved
# 2016-01-04        Recompletion     N        13606
#
#                  Stacked_Lateral_Parent_Well_DP Current_Queue  \
# Permit_approved
# 2016-01-04                                  NaN      APPROVED
#
#                 Permit_submitted Approval_time       SHALE  Approved_year
# Permit_approved
# 2016-01-04            2016-01-04        0 days  EAGLE FORD           2016

# %%
prod_16.head(1)
# Out:
#     Lease_Name Lease_No. District Well  Oil_BBL  Casinghead_MCF  GW_Gas_MCF  \
# 0  ALTIZER "B"    167077       01   7B        0               0       29948
#
#    Condensate_BBL  Production_year
# 0               0             2016

# %%
test = permits.merge(prod_16, how='left',left_on=['Approved_year','Lease_Name'], right_on=['Production_year','Lease_Name'])

# %%
test.T
# Out:
#                                                                   0       \
# Permit_approved                                      2016-01-04 00:00:00
# Status_Date                     Submitted 01/04/2016 Approved 01/04/2016
# Status                                                            812976
# API_NO.                                                         28531642
# Operator_Name_Number                     CANTERA OPERATING, LLC (129692)
# Lease_Name                                            O. A. LAMPLEY GU 1
# Well_x                                                                 1
# District_x                                                            02
# County                                                            LAVACA
# Wellbore_Profile                                                Vertical
# Filing_Purpose                                              Recompletion
# Amend                                                                  N
# Total_Depth                                                        13606
# Stacked_Lateral_Parent_Well_DP                                       NaN
# Current_Queue                                                   APPROVED
# Permit_submitted                                              2016-01-04
# Approval_time                                                     0 days
# SHALE                                                         EAGLE FORD
# Approved_year                                                       2016
# Lease_No.                                                         173951
# District_y                                                            02
# Well_y                                                                 7
# Oil_BBL                                                              0.0
# Casinghead_MCF                                                       0.0
# GW_Gas_MCF                                                           0.0
# Condensate_BBL                                                       0.0
# Production_year                                                   2016.0
#
#                                                                   1       \
# Permit_approved                                      2016-01-04 00:00:00
# Status_Date                     Submitted 01/04/2016 Approved 01/04/2016
# Status                                                            812976
# API_NO.                                                         28531642
# Operator_Name_Number                     CANTERA OPERATING, LLC (129692)
# Lease_Name                                            O. A. LAMPLEY GU 1
# Well_x                                                                 1
# District_x                                                            02
# County                                                            LAVACA
# Wellbore_Profile                                                Vertical
# Filing_Purpose                                              Recompletion
# Amend                                                                  N
# Total_Depth                                                        13606
# Stacked_Lateral_Parent_Well_DP                                       NaN
# Current_Queue                                                   APPROVED
# Permit_submitted                                              2016-01-04
# Approval_time                                                     0 days
# SHALE                                                         EAGLE FORD
# Approved_year                                                       2016
# Lease_No.                                                         175280
# District_y                                                            02
# Well_y                                                                 8
# Oil_BBL                                                              0.0
# Casinghead_MCF                                                       0.0
# GW_Gas_MCF                                                           0.0
# Condensate_BBL                                                       0.0
# Production_year                                                   2016.0
#
#                                                                   2       \
# Permit_approved                                      2016-01-04 00:00:00
# Status_Date                     Submitted 01/04/2016 Approved 01/04/2016
# Status                                                            812976
# API_NO.                                                         28531642
# Operator_Name_Number                     CANTERA OPERATING, LLC (129692)
# Lease_Name                                            O. A. LAMPLEY GU 1
# Well_x                                                                 1
# District_x                                                            02
# County                                                            LAVACA
# Wellbore_Profile                                                Vertical
# Filing_Purpose                                              Recompletion
# Amend                                                                  N
# Total_Depth                                                        13606
# Stacked_Lateral_Parent_Well_DP                                       NaN
# Current_Queue                                                   APPROVED
# Permit_submitted                                              2016-01-04
# Approval_time                                                     0 days
# SHALE                                                         EAGLE FORD
# Approved_year                                                       2016
# Lease_No.                                                         175890
# District_y                                                            02
# Well_y                                                                 9
# Oil_BBL                                                              0.0
# Casinghead_MCF                                                       0.0
# GW_Gas_MCF                                                           0.0
# Condensate_BBL                                                       0.0
# Production_year                                                   2016.0
#
#                                                                   3       \
# Permit_approved                                      2016-01-04 00:00:00
# Status_Date                     Submitted 01/04/2016 Approved 01/04/2016
# Status                                                            812976
# API_NO.                                                         28531642
# Operator_Name_Number                     CANTERA OPERATING, LLC (129692)
# Lease_Name                                            O. A. LAMPLEY GU 1
# Well_x                                                                 1
# District_x                                                            02
# County                                                            LAVACA
# Wellbore_Profile                                                Vertical
# Filing_Purpose                                              Recompletion
# Amend                                                                  N
# Total_Depth                                                        13606
# Stacked_Lateral_Parent_Well_DP                                       NaN
# Current_Queue                                                   APPROVED
# Permit_submitted                                              2016-01-04
# Approval_time                                                     0 days
# SHALE                                                         EAGLE FORD
# Approved_year                                                       2016
# Lease_No.                                                         177327
# District_y                                                            02
# Well_y                                                                11
# Oil_BBL                                                              0.0
# Casinghead_MCF                                                       0.0
# GW_Gas_MCF                                                           0.0
# Condensate_BBL                                                       0.0
# Production_year                                                   2016.0
#
#                                                                   4       \
# Permit_approved                                      2016-01-04 00:00:00
# Status_Date                     Submitted 01/04/2016 Approved 01/04/2016
# Status                                                            812976
# API_NO.                                                         28531642
# Operator_Name_Number                     CANTERA OPERATING, LLC (129692)
# Lease_Name                                            O. A. LAMPLEY GU 1
# Well_x                                                                 1
# District_x                                                            02
# County                                                            LAVACA
# Wellbore_Profile                                                Vertical
# Filing_Purpose                                              Recompletion
# Amend                                                                  N
# Total_Depth                                                        13606
# Stacked_Lateral_Parent_Well_DP                                       NaN
# Current_Queue                                                   APPROVED
# Permit_submitted                                              2016-01-04
# Approval_time                                                     0 days
# SHALE                                                         EAGLE FORD
# Approved_year                                                       2016
# Lease_No.                                                         178752
# District_y                                                            02
# Well_y                                                                13
# Oil_BBL                                                              0.0
# Casinghead_MCF                                                       0.0
# GW_Gas_MCF                                                           0.0
# Condensate_BBL                                                       0.0
# Production_year                                                   2016.0
#
#                                                                   5       \
# Permit_approved                                      2016-01-04 00:00:00
# Status_Date                     Submitted 01/04/2016 Approved 01/04/2016
# Status                                                            812976
# API_NO.                                                         28531642
# Operator_Name_Number                     CANTERA OPERATING, LLC (129692)
# Lease_Name                                            O. A. LAMPLEY GU 1
# Well_x                                                                 1
# District_x                                                            02
# County                                                            LAVACA
# Wellbore_Profile                                                Vertical
# Filing_Purpose                                              Recompletion
# Amend                                                                  N
# Total_Depth                                                        13606
# Stacked_Lateral_Parent_Well_DP                                       NaN
# Current_Queue                                                   APPROVED
# Permit_submitted                                              2016-01-04
# Approval_time                                                     0 days
# SHALE                                                         EAGLE FORD
# Approved_year                                                       2016
# Lease_No.                                                         191749
# District_y                                                            02
# Well_y                                                                15
# Oil_BBL                                                              0.0
# Casinghead_MCF                                                       0.0
# GW_Gas_MCF                                                           0.0
# Condensate_BBL                                                       0.0
# Production_year                                                   2016.0
#
#                                                                   6       \
# Permit_approved                                      2016-01-04 00:00:00
# Status_Date                     Submitted 01/04/2016 Approved 01/04/2016
# Status                                                            812976
# API_NO.                                                         28531642
# Operator_Name_Number                     CANTERA OPERATING, LLC (129692)
# Lease_Name                                            O. A. LAMPLEY GU 1
# Well_x                                                                 1
# District_x                                                            02
# County                                                            LAVACA
# Wellbore_Profile                                                Vertical
# Filing_Purpose                                              Recompletion
# Amend                                                                  N
# Total_Depth                                                        13606
# Stacked_Lateral_Parent_Well_DP                                       NaN
# Current_Queue                                                   APPROVED
# Permit_submitted                                              2016-01-04
# Approval_time                                                     0 days
# SHALE                                                         EAGLE FORD
# Approved_year                                                       2016
# Lease_No.                                                         205897
# District_y                                                            02
# Well_y                                                                16
# Oil_BBL                                                              0.0
# Casinghead_MCF                                                       0.0
# GW_Gas_MCF                                                        1058.0
# Condensate_BBL                                                       0.0
# Production_year                                                   2016.0
#
#                                                                   7       \
# Permit_approved                                      2016-01-04 00:00:00
# Status_Date                     Submitted 01/04/2016 Approved 01/04/2016
# Status                                                            812976
# API_NO.                                                         28531642
# Operator_Name_Number                     CANTERA OPERATING, LLC (129692)
# Lease_Name                                            O. A. LAMPLEY GU 1
# Well_x                                                                 1
# District_x                                                            02
# County                                                            LAVACA
# Wellbore_Profile                                                Vertical
# Filing_Purpose                                              Recompletion
# Amend                                                                  N
# Total_Depth                                                        13606
# Stacked_Lateral_Parent_Well_DP                                       NaN
# Current_Queue                                                   APPROVED
# Permit_submitted                                              2016-01-04
# Approval_time                                                     0 days
# SHALE                                                         EAGLE FORD
# Approved_year                                                       2016
# Lease_No.                                                         218985
# District_y                                                            02
# Well_y                                                                 8
# Oil_BBL                                                              0.0
# Casinghead_MCF                                                       0.0
# GW_Gas_MCF                                                           0.0
# Condensate_BBL                                                       0.0
# Production_year                                                   2016.0
#
#                                                                   8       \
# Permit_approved                                      2016-01-04 00:00:00
# Status_Date                     Submitted 01/04/2016 Approved 01/04/2016
# Status                                                            812976
# API_NO.                                                         28531642
# Operator_Name_Number                     CANTERA OPERATING, LLC (129692)
# Lease_Name                                            O. A. LAMPLEY GU 1
# Well_x                                                                 1
# District_x                                                            02
# County                                                            LAVACA
# Wellbore_Profile                                                Vertical
# Filing_Purpose                                              Recompletion
# Amend                                                                  N
# Total_Depth                                                        13606
# Stacked_Lateral_Parent_Well_DP                                       NaN
# Current_Queue                                                   APPROVED
# Permit_submitted                                              2016-01-04
# Approval_time                                                     0 days
# SHALE                                                         EAGLE FORD
# Approved_year                                                       2016
# Lease_No.                                                         237961
# District_y                                                            02
# Well_y                                                                13
# Oil_BBL                                                              0.0
# Casinghead_MCF                                                       0.0
# GW_Gas_MCF                                                       26090.0
# Condensate_BBL                                                       0.0
# Production_year                                                   2016.0
#
#                                                                   9       ...  \
# Permit_approved                                      2016-01-04 00:00:00  ...
# Status_Date                     Submitted 01/04/2016 Approved 01/04/2016  ...
# Status                                                            812976  ...
# API_NO.                                                         28531642  ...
# Operator_Name_Number                     CANTERA OPERATING, LLC (129692)  ...
# Lease_Name                                            O. A. LAMPLEY GU 1  ...
# Well_x                                                                 1  ...
# District_x                                                            02  ...
# County                                                            LAVACA  ...
# Wellbore_Profile                                                Vertical  ...
# Filing_Purpose                                              Recompletion  ...
# Amend                                                                  N  ...
# Total_Depth                                                        13606  ...
# Stacked_Lateral_Parent_Well_DP                                       NaN  ...
# Current_Queue                                                   APPROVED  ...
# Permit_submitted                                              2016-01-04  ...
# Approval_time                                                     0 days  ...
# SHALE                                                         EAGLE FORD  ...
# Approved_year                                                       2016  ...
# Lease_No.                                                         277235  ...
# District_y                                                            02  ...
# Well_y                                                                 9  ...
# Oil_BBL                                                              0.0  ...
# Casinghead_MCF                                                       0.0  ...
# GW_Gas_MCF                                                           0.0  ...
# Condensate_BBL                                                       0.0  ...
# Production_year                                                   2016.0  ...
#
#                                                                   149714  \
# Permit_approved                                      2021-12-30 00:00:00
# Status_Date                     Submitted 12/27/2021 Approved 12/30/2021
# Status                                                            875591
# API_NO.                                                           132812
# Operator_Name_Number                  TRUEBLOOD RESOURCES, INC. (871506)
# Lease_Name                                                    FITZGERALD
# Well_x                                                                 3
# District_x                                                            06
# County                                                          ANDERSON
# Wellbore_Profile                                                Vertical
# Filing_Purpose                                                 New Drill
# Amend                                                                  N
# Total_Depth                                                          670
# Stacked_Lateral_Parent_Well_DP                                       NaN
# Current_Queue                                                   APPROVED
# Permit_submitted                                              2021-12-27
# Approval_time                                                     3 days
# SHALE                                                               NONE
# Approved_year                                                       2021
# Lease_No.                                                            NaN
# District_y                                                           NaN
# Well_y                                                               NaN
# Oil_BBL                                                              NaN
# Casinghead_MCF                                                       NaN
# GW_Gas_MCF                                                           NaN
# Condensate_BBL                                                       NaN
# Production_year                                                      NaN
#
#                                                                   149715  \
# Permit_approved                                      2021-12-30 00:00:00
# Status_Date                     Submitted 12/25/2021 Approved 12/30/2021
# Status                                                            875575
# API_NO.                                                           132809
# Operator_Name_Number                  TRUEBLOOD RESOURCES, INC. (871506)
# Lease_Name                                                    FITZGERALD
# Well_x                                                                 2
# District_x                                                            06
# County                                                          ANDERSON
# Wellbore_Profile                                                Vertical
# Filing_Purpose                                                 New Drill
# Amend                                                                  N
# Total_Depth                                                          670
# Stacked_Lateral_Parent_Well_DP                                       NaN
# Current_Queue                                                   APPROVED
# Permit_submitted                                              2021-12-25
# Approval_time                                                     5 days
# SHALE                                                               NONE
# Approved_year                                                       2021
# Lease_No.                                                            NaN
# District_y                                                           NaN
# Well_y                                                               NaN
# Oil_BBL                                                              NaN
# Casinghead_MCF                                                       NaN
# GW_Gas_MCF                                                           NaN
# Condensate_BBL                                                       NaN
# Production_year                                                      NaN
#
#                                                                   149716  \
# Permit_approved                                      2021-12-30 00:00:00
# Status_Date                     Submitted 11/29/2021 Approved 12/30/2021
# Status                                                            860176
# API_NO.                                                         46141412
# Operator_Name_Number             PIONEER NATURAL RES. USA, INC. (665748)
# Lease_Name                                           NORTH BROOK 38-37EB
# Well_x                                                              102H
# District_x                                                            7C
# County                                                             UPTON
# Wellbore_Profile                                              Horizontal
# Filing_Purpose                                                 New Drill
# Amend                                                                  Y
# Total_Depth                                                        10714
# Stacked_Lateral_Parent_Well_DP                                       NaN
# Current_Queue                                                   APPROVED
# Permit_submitted                                              2021-11-29
# Approval_time                                                    31 days
# SHALE                                                      PERMIAN BASIN
# Approved_year                                                       2021
# Lease_No.                                                            NaN
# District_y                                                           NaN
# Well_y                                                               NaN
# Oil_BBL                                                              NaN
# Casinghead_MCF                                                       NaN
# GW_Gas_MCF                                                           NaN
# Condensate_BBL                                                       NaN
# Production_year                                                      NaN
#
#                                                                   149717  \
# Permit_approved                                      2021-12-30 00:00:00
# Status_Date                     Submitted 11/29/2021 Approved 12/30/2021
# Status                                                            860180
# API_NO.                                                         46141414
# Operator_Name_Number             PIONEER NATURAL RES. USA, INC. (665748)
# Lease_Name                                           NORTH BROOK 38-37ED
# Well_x                                                              104H
# District_x                                                            7C
# County                                                             UPTON
# Wellbore_Profile                                              Horizontal
# Filing_Purpose                                                 New Drill
# Amend                                                                  Y
# Total_Depth                                                        10714
# Stacked_Lateral_Parent_Well_DP                                       NaN
# Current_Queue                                                   APPROVED
# Permit_submitted                                              2021-11-29
# Approval_time                                                    31 days
# SHALE                                                      PERMIAN BASIN
# Approved_year                                                       2021
# Lease_No.                                                            NaN
# District_y                                                           NaN
# Well_y                                                               NaN
# Oil_BBL                                                              NaN
# Casinghead_MCF                                                       NaN
# GW_Gas_MCF                                                           NaN
# Condensate_BBL                                                       NaN
# Production_year                                                      NaN
#
#                                                                   149718  \
# Permit_approved                                      2021-12-30 00:00:00
# Status_Date                     Submitted 12/20/2021 Approved 12/30/2021
# Status                                                            875461
# API_NO.                                                         38939738
# Operator_Name_Number                     COLGATE OPERATING, LLC (167327)
# Lease_Name                                          CAPE BUFFALO 12-11 G
# Well_x                                                             1205H
# District_x                                                            08
# County                                                            REEVES
# Wellbore_Profile                                              Horizontal
# Filing_Purpose                                                 New Drill
# Amend                                                                  N
# Total_Depth                                                        11500
# Stacked_Lateral_Parent_Well_DP                                       NaN
# Current_Queue                                                   APPROVED
# Permit_submitted                                              2021-12-20
# Approval_time                                                    10 days
# SHALE                                                      PERMIAN BASIN
# Approved_year                                                       2021
# Lease_No.                                                            NaN
# District_y                                                           NaN
# Well_y                                                               NaN
# Oil_BBL                                                              NaN
# Casinghead_MCF                                                       NaN
# GW_Gas_MCF                                                           NaN
# Condensate_BBL                                                       NaN
# Production_year                                                      NaN
#
#                                                                   149719  \
# Permit_approved                                      2021-12-30 00:00:00
# Status_Date                     Submitted 12/20/2021 Approved 12/30/2021
# Status                                                            875460
# API_NO.                                                         38939737
# Operator_Name_Number                     COLGATE OPERATING, LLC (167327)
# Lease_Name                                          CAPE BUFFALO 12-11 F
# Well_x                                                             1304H
# District_x                                                            08
# County                                                            REEVES
# Wellbore_Profile                                              Horizontal
# Filing_Purpose                                                 New Drill
# Amend                                                                  N
# Total_Depth                                                        11000
# Stacked_Lateral_Parent_Well_DP                                       NaN
# Current_Queue                                                   APPROVED
# Permit_submitted                                              2021-12-20
# Approval_time                                                    10 days
# SHALE                                                      PERMIAN BASIN
# Approved_year                                                       2021
# Lease_No.                                                            NaN
# District_y                                                           NaN
# Well_y                                                               NaN
# Oil_BBL                                                              NaN
# Casinghead_MCF                                                       NaN
# GW_Gas_MCF                                                           NaN
# Condensate_BBL                                                       NaN
# Production_year                                                      NaN
#
#                                                                   149720  \
# Permit_approved                                      2021-12-30 00:00:00
# Status_Date                     Submitted 12/20/2021 Approved 12/30/2021
# Status                                                            875459
# API_NO.                                                         38939736
# Operator_Name_Number                     COLGATE OPERATING, LLC (167327)
# Lease_Name                                          CAPE BUFFALO 12-11 E
# Well_x                                                              225H
# District_x                                                            08
# County                                                            REEVES
# Wellbore_Profile                                              Horizontal
# Filing_Purpose                                                 New Drill
# Amend                                                                  N
# Total_Depth                                                        11000
# Stacked_Lateral_Parent_Well_DP                                       NaN
# Current_Queue                                                   APPROVED
# Permit_submitted                                              2021-12-20
# Approval_time                                                    10 days
# SHALE                                                      PERMIAN BASIN
# Approved_year                                                       2021
# Lease_No.                                                            NaN
# District_y                                                           NaN
# Well_y                                                               NaN
# Oil_BBL                                                              NaN
# Casinghead_MCF                                                       NaN
# GW_Gas_MCF                                                           NaN
# Condensate_BBL                                                       NaN
# Production_year                                                      NaN
#
#                                                                   149721  \
# Permit_approved                                      2021-12-30 00:00:00
# Status_Date                     Submitted 12/20/2021 Approved 12/30/2021
# Status                                                            875458
# API_NO.                                                         38939735
# Operator_Name_Number                     COLGATE OPERATING, LLC (167327)
# Lease_Name                                          CAPE BUFFALO 12-11 D
# Well_x                                                              224H
# District_x                                                            08
# County                                                            REEVES
# Wellbore_Profile                                              Horizontal
# Filing_Purpose                                                 New Drill
# Amend                                                                  N
# Total_Depth                                                        11000
# Stacked_Lateral_Parent_Well_DP                                       NaN
# Current_Queue                                                   APPROVED
# Permit_submitted                                              2021-12-20
# Approval_time                                                    10 days
# SHALE                                                      PERMIAN BASIN
# Approved_year                                                       2021
# Lease_No.                                                            NaN
# District_y                                                           NaN
# Well_y                                                               NaN
# Oil_BBL                                                              NaN
# Casinghead_MCF                                                       NaN
# GW_Gas_MCF                                                           NaN
# Condensate_BBL                                                       NaN
# Production_year                                                      NaN
#
#                                                                   149722  \
# Permit_approved                                      2021-12-30 00:00:00
# Status_Date                     Submitted 09/23/2021 Approved 12/30/2021
# Status                                                            872590
# API_NO.                                                         38939613
# Operator_Name_Number               TALL CITY OPERATIONS III LLC (835518)
# Lease_Name                                         CONGER UNIT 185-184 B
# Well_x                                                                3H
# District_x                                                            08
# County                                                            REEVES
# Wellbore_Profile                                              Horizontal
# Filing_Purpose                                                 New Drill
# Amend                                                                  Y
# Total_Depth                                                        16000
# Stacked_Lateral_Parent_Well_DP                                       NaN
# Current_Queue                                                   APPROVED
# Permit_submitted                                              2021-09-23
# Approval_time                                                    98 days
# SHALE                                                      PERMIAN BASIN
# Approved_year                                                       2021
# Lease_No.                                                            NaN
# District_y                                                           NaN
# Well_y                                                               NaN
# Oil_BBL                                                              NaN
# Casinghead_MCF                                                       NaN
# GW_Gas_MCF                                                           NaN
# Condensate_BBL                                                       NaN
# Production_year                                                      NaN
#
#                                                                   149723
# Permit_approved                                      2021-12-30 00:00:00
# Status_Date                     Submitted 12/28/2021 Approved 12/30/2021
# Status                                                            875610
# API_NO.                                                         38939739
# Operator_Name_Number                  WATERBRIDGE STATELINE LLC (900327)
# Lease_Name                                                    CENTRAL 27
# Well_x                                                                1D
# District_x                                                            08
# County                                                            REEVES
# Wellbore_Profile                                                Vertical
# Filing_Purpose                                                 New Drill
# Amend                                                                  N
# Total_Depth                                                         7800
# Stacked_Lateral_Parent_Well_DP                                       NaN
# Current_Queue                                                   APPROVED
# Permit_submitted                                              2021-12-28
# Approval_time                                                     2 days
# SHALE                                                      PERMIAN BASIN
# Approved_year                                                       2021
# Lease_No.                                                            NaN
# District_y                                                           NaN
# Well_y                                                               NaN
# Oil_BBL                                                              NaN
# Casinghead_MCF                                                       NaN
# GW_Gas_MCF                                                           NaN
# Condensate_BBL                                                       NaN
# Production_year                                                      NaN
#
# [27 rows x 149724 columns]

# %%
test.isna().sum()
# Out:
# Permit_approved                        0
# Status_Date                            0
# Status                                 0
# API_NO.                                0
# Operator_Name_Number                   0
# Lease_Name                             0
# Well_x                                 0
# District_x                             0
# County                                 0
# Wellbore_Profile                       5
# Filing_Purpose                         0
# Amend                                  0
# Total_Depth                            0
# Stacked_Lateral_Parent_Well_DP    142789
# Current_Queue                          0
# Permit_submitted                       0
# Approval_time                          0
# SHALE                                  2
# Approved_year                          0
# Lease_No.                          69939
# District_y                         69939
# Well_y                             69939
# Oil_BBL                            69939
# Casinghead_MCF                     69939
# GW_Gas_MCF                         69939
# Condensate_BBL                     69939
# Production_year                    69939
# dtype: int64

# %%
test.dropna(how=)
# Out:
#       Permit_approved                               Status_Date  Status  \
# 71         2016-01-05  Submitted 12/07/2015 Approved 01/05/2016  802467
# 72         2016-01-05  Submitted 12/07/2015 Approved 01/05/2016  802462
# 355        2016-01-05  Submitted 01/02/2016 Approved 01/05/2016  719416
# 356        2016-01-05  Submitted 01/02/2016 Approved 01/05/2016  719416
# 571        2016-01-06  Submitted 01/05/2016 Approved 01/06/2016  810059
# ...               ...                                       ...     ...
# 82718      2016-12-30  Submitted 12/15/2016 Approved 12/30/2016  820372
# 82722      2016-12-30  Submitted 12/15/2016 Approved 12/30/2016  820365
# 82747      2016-12-30  Submitted 12/15/2016 Approved 12/30/2016  820369
# 82749      2016-12-30  Submitted 12/09/2016 Approved 12/30/2016  817335
# 82756      2016-12-30  Submitted 12/09/2016 Approved 12/30/2016  817116
#
#         API_NO.                       Operator_Name_Number  \
# 71     17337100     ENERGEN RESOURCES CORPORATION (252002)
# 72     17337098     ENERGEN RESOURCES CORPORATION (252002)
# 355    48333272     SANGUINE GAS EXPLORATION, LLC (748059)
# 356    48333272     SANGUINE GAS EXPLORATION, LLC (748059)
# 571    38339484   AMERICAN ENERGY-PERM BASIN, LLC (017996)
# ...         ...                                        ...
# 82718  12334336  BURLINGTON RESOURCES O & G CO LP (109333)
# 82722  12334337  BURLINGTON RESOURCES O & G CO LP (109333)
# 82747  12334334  BURLINGTON RESOURCES O & G CO LP (109333)
# 82749  17337436                  HUNT OIL COMPANY (416330)
# 82756  17337430                  HUNT OIL COMPANY (416330)
#
#                  Lease_Name   Well_x District_x     County Wellbore_Profile  \
# 71         FRIO NS 34-39 03     103H         08  GLASSCOCK       Horizontal
# 72         FRIO NS 34-39 02     102H         08  GLASSCOCK       Horizontal
# 355                    HINK   H306SL         10    WHEELER       Horizontal
# 356                    HINK   H306SL         10    WHEELER       Horizontal
# 571          ROCKER B 20-21     32HA         7C     REAGAN       Horizontal
# ...                     ...      ...        ...        ...              ...
# 82718  R W PAWLIK JR UNIT A      402         02    DE WITT       Horizontal
# 82722  R W PAWLIK JR UNIT A      202         02    DE WITT       Horizontal
# 82747  R W PAWLIK JR UNIT A      302         02    DE WITT       Horizontal
# 82749   HARRIS-HUTCHISON 50    205HL         08  GLASSCOCK       Horizontal
# 82756   HARRIS-HUTCHISON 60    206HL         08  GLASSCOCK       Horizontal
#
#        ...          SHALE Approved_year  Lease_No.  District_y Well_y  \
# 71     ...  PERMIAN BASIN          2016      47803          08
# 72     ...  PERMIAN BASIN          2016      47687          08
# 355    ...           NONE          2016     023717          10      1
# 356    ...           NONE          2016      08116          10
# 571    ...  PERMIAN BASIN          2016      18677          7C
# ...    ...            ...           ...        ...         ...    ...
# 82718  ...     EAGLE FORD          2016      10093          02
# 82722  ...     EAGLE FORD          2016      10093          02
# 82747  ...     EAGLE FORD          2016      10093          02
# 82749  ...  PERMIAN BASIN          2016      46568          08
# 82756  ...  PERMIAN BASIN          2016      47431          08
#
#         Oil_BBL Casinghead_MCF GW_Gas_MCF  Condensate_BBL Production_year
# 71     205017.0       567480.0        0.0             0.0          2016.0
# 72     160160.0       500274.0        0.0             0.0          2016.0
# 355         0.0            0.0     9479.0             0.0          2016.0
# 356     36155.0       121686.0        0.0             0.0          2016.0
# 571    197031.0       680702.0        0.0             0.0          2016.0
# ...         ...            ...        ...             ...             ...
# 82718   15152.0        26494.0        0.0             0.0          2016.0
# 82722   15152.0        26494.0        0.0             0.0          2016.0
# 82747   15152.0        26494.0        0.0             0.0          2016.0
# 82749   30492.0        60507.0        0.0             0.0          2016.0
# 82756   54742.0       151107.0        0.0             0.0          2016.0
#
# [465 rows x 27 columns]
